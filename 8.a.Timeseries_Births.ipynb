# %% [markdown]
# <a href="https://colab.research.google.com/github/bsong75/brendensong.github.io/blob/main/8.a.Timeseries_Births.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
birth=pd.read_csv('/content/dailybirth.csv')

# %%
birth
# Out:
#            Date  Births
# 0    1959-01-01      35
# 1    1959-01-02      32
# 2    1959-01-03      30
# 3    1959-01-04      31
# 4    1959-01-05      44
# ..          ...     ...
# 360  1959-12-27      37
# 361  1959-12-28      52
# 362  1959-12-29      48
# 363  1959-12-30      55
# 364  1959-12-31      50
#
# [365 rows x 2 columns]

# %%
birth['Date']=pd.to_datetime(birth.Date)

# %%
birth.dtypes
# Out:
# Date      datetime64[ns]
# Births             int64
# dtype: object

# %%
x = birth.Date
y = birth.Births

# %%
# Using plotly.express
import plotly.express as px

fig = px.line(birth, x='Date', y="Births")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ddbce472-5c51-4795-ae15-cf830a28db3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ddbce472-5c51-4795-ae15-cf830a28db3c")) {
#                     Plotly.newPlot(
#                         'ddbce472-5c51-4795-ae15-cf830a28db3c',
# ...

# %%
import plotly.graph_objects as go
fig2 = go.Figure([go.Scatter(x=birth['Date'], y=birth['Births'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="43eff14a-c8f8-4d4f-bd22-5ff3e66e99f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43eff14a-c8f8-4d4f-bd22-5ff3e66e99f2")) {
#                     Plotly.newPlot(
#                         '43eff14a-c8f8-4d4f-bd22-5ff3e66e99f2',
# ...

# %%
import matplotlib.pyplot as plt 
fig, ax = plt.subplots(figsize=(20,6))

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
predictions = []
actual = series.values[1:]
rmse = sqrt(mean_squared_error(actual, predictions))
